# %%
import pandas as pd 
df = pd.read_csv('covid_19_data.csv')
df
# Out:
#            SNo ObservationDate                  Province/State  \
# 0            1      01/22/2020                           Anhui
# 1            2      01/22/2020                         Beijing
# 2            3      01/22/2020                       Chongqing
# 3            4      01/22/2020                          Fujian
# 4            5      01/22/2020                           Gansu
# 5            6      01/22/2020                       Guangdong
# 6            7      01/22/2020                         Guangxi
# 7            8      01/22/2020                         Guizhou
# 8            9      01/22/2020                          Hainan
# 9           10      01/22/2020                           Hebei
# 10          11      01/22/2020                    Heilongjiang
# 11          12      01/22/2020                           Henan
# 12          13      01/22/2020                       Hong Kong
# 13          14      01/22/2020                           Hubei
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            SNo ObservationDate                  Province/State  \
# 0            1      01/22/2020                           Anhui
# 1            2      01/22/2020                         Beijing
# 2            3      01/22/2020                       Chongqing
# 3            4      01/22/2020                          Fujian
# 4            5      01/22/2020                           Gansu
# 5            6      01/22/2020                       Guangdong
# 6            7      01/22/2020                         Guangxi
# 7            8      01/22/2020                         Guizhou
# 8            9      01/22/2020                          Hainan
# 9           10      01/22/2020                           Hebei
# 10          11      01/22/2020                    Heilongjiang
# 11          12      01/22/2020                           Henan
# 12          13      01/22/2020                       Hong Kong
# ...

# %%
df.head(10)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# ...

# %%
#describe the shape 
df.shape
# Out:
# (306429, 8)

# %%
#describe the size 
df.size
# Out:
# 2451432

# %%
#shjow data types 
df.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
#show the column names in the dataset
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
#check for null values and sum of nul values on every column

df.notnull().sum # if it returns true, then there is no null value in the column

#df.isnull().sum # it will return false if there is no null value. The .sum functions calculates the sum of false or true values
# Out:
# <bound method DataFrame.sum of          SNo  ObservationDate  Province/State  Country/Region  Last Update  \
# 0       True             True            True            True         True
# 1       True             True            True            True         True
# 2       True             True            True            True         True
# 3       True             True            True            True         True
# 4       True             True            True            True         True
# 5       True             True            True            True         True
# 6       True             True            True            True         True
# 7       True             True            True            True         True
# 8       True             True            True            True         True
# 9       True             True            True            True         True
# 10      True             True            True            True         True
# ...

# %%
#use seaborn to creat a graph showing null values 

#there is no nul values.
# Out:
#   File "<ipython-input-9-fa14924d1910>", line 3
#     there is no nul values.
#                   ^
# SyntaxError: invalid syntax

# %%
#checkl for duplicates in data

df.duplicated() # it will return false if there are no duplicates.  in this case they are zero
df.duplicated().sum() #The .sum function returns the totalk number of duplicates.
df[df.duplicated()] # it wil display the diplicated columns

# %%
#remove duplicates if available 
#suppose there were duplicates, the following comnmand would remove the duplicates
#use df.shape to compare the initial number of rows and the current number after dropping duplicates.
df.drop_duplicates(inplace=True)
df.shape

# %%
#determine the total number of deaths, recovered and confirmed cases in mainland china. 
#df.head(50)
#df[df['Country/Region'].isin(['Mainland China'])].sum()
df[df['Country/Region'].str.contains('Mainland China')].sum()   THE TWO METHODS WORKS JUST FINE

# %%
#which state in mainland china recorded the highest number of confirmed cases in 2020
df.head(2)
df[ (df['Country/Region'] == 'Mainland China') & (df['DATA_N'] == '2021')] ['Confirmed'].sum()

# %%
#total number of deaths in 2020 and 2021
df.head(4)
df['DATA_N'] = pd.to_datetime(df['Last Update'])

# %%
df['DATA_N'].dt.year.value_counts()

# %%
#highest and lowest number of recovery cases 
df['Recovered'].value_counts('dropna=False')

# %%
#highest and lowest number of deaths 
df[('Deaths')].describe()

# %%
#draw several graphs usings matploylib and seasborn library

# %%
#for Japan What is the number of confirmed cases, deaths and recovered (use the string and isin method)
df.head(2)
Y= df[df['Country/Region'].isin(['Japan'])]
Y[['Confirmed','Deaths','Recovered']].sum()

# %%
#which year has the highest number of COVID cases and deaths
df['DATA_K'] = pd.to_datetime(df['ObservationDate'])
df.groupby('DATA_K').Deaths.count()
# Out:
# DATA_K
# 2020-01-22     40
# 2020-01-23     48
# 2020-01-24     43
# 2020-01-25     46
# 2020-01-26     49
# 2020-01-27     53
# 2020-01-28     54
# 2020-01-29     56
# 2020-01-30     60
# 2020-01-31     64
# 2020-02-01     69
# 2020-02-02     69
# 2020-02-03     70
# 2020-02-04     72
# 2020-02-05     73
# 2020-02-06     73
# 2020-02-07     74
# 2020-02-08     74
# 2020-02-09     74
# 2020-02-10     74
# 2020-02-11     75
# 2020-02-12     75
# 2020-02-13     76
# 2020-02-14     77
# 2020-02-15     77
# 2020-02-16     77
# 2020-02-17     77
# 2020-02-18     77
# 2020-02-19     78
# 2020-02-20     78
#              ...
# 2021-04-30    765
# 2021-05-01    765
# 2021-05-02    765
# 2021-05-03    765
# 2021-05-04    765
# 2021-05-05    765
# 2021-05-06    765
# 2021-05-07    765
# 2021-05-08    765
# 2021-05-09    765
# 2021-05-10    765
# 2021-05-11    765
# 2021-05-12    765
# 2021-05-13    765
# 2021-05-14    765
# 2021-05-15    765
# 2021-05-16    765
# 2021-05-17    765
# ...

# %%
#which year has the lowest number of COVID confirmed, deaths, and recovered cases

df['YEAR'] = df['DATA_K'].dt.year
df.groupby('YEAR').count()

# %%
import seaborn as sbs
sbs.countplot(df['Country/Region'])

# %%
#which country has the highest number of COVID recovered cases. show using a graph 

import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline
x = df['Country/Region']
y=df['Recovered']

fig=plt.figure()
plt.ylabel('Recovered')
plt.title('Country')

data= plt.plot(x, y, 'b')

plt.hist
plt.show()
fig.savefig('my_figure2.png')

# %%
#how many country regions are in the dataset ( use unique fucntion)
df['Province/State'].describe()

# %%
#how many country regions are in the dataset. show in a graph. use seaborn

import seaborn as sbn
sbn.countplot(df['Province/State'])

# %%
#show the total number of confirmed cases that were found in Taiwan in 2021
#df.head(3)
df['DATA_E'] = pd.to_datetime(df['ObservationDate'])
df.head(3)
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered     DATA_K  YEAR     DATA_E
# 0        1.0     0.0        0.0 2020-01-22  2020 2020-01-22
# 1       14.0     0.0        0.0 2020-01-22  2020 2020-01-22
# 2        6.0     0.0        0.0 2020-01-22  2020 2020-01-22

# %%
#show an example using the parameter (value_count)
df['Country/Region'].value_counts()
# Out:
# Russia                            30251
# US                                26740
# Japan                             18059
# Mainland China                    15758
# India                             13182
# Colombia                          12503
# Mexico                            12282
# Brazil                            10229
# Ukraine                            9891
# Peru                               9625
# Italy                              8105
# Spain                              7718
# Sweden                             7665
# Canada                             6960
# UK                                 6674
# Germany                            6584
# Chile                              6453
# Netherlands                        5999
# France                             5024
# Australia                          3788
# Belgium                            2670
# Pakistan                           2583
# Denmark                            1340
# ...

# %%
#show an instance of using both "AND" and "OR"
h= df[(df['Country/Region'] == 'Mainland China') & (df['Province/State'] == 'Anhui') | (df['Province/State'] == 'Beijing')]
h
# Out:
#            SNo ObservationDate Province/State  Country/Region  \
# 0            1      01/22/2020          Anhui  Mainland China
# 1            2      01/22/2020        Beijing  Mainland China
# 40          41      01/23/2020          Anhui  Mainland China
# 41          42      01/23/2020        Beijing  Mainland China
# 91          92      01/24/2020        Beijing  Mainland China
# 99         100      01/24/2020          Anhui  Mainland China
# 136        137      01/25/2020        Beijing  Mainland China
# 137        138      01/25/2020          Anhui  Mainland China
# 183        184      01/26/2020        Beijing  Mainland China
# 184        185      01/26/2020          Anhui  Mainland China
# 232        233      01/27/2020        Beijing  Mainland China
# 235        236      01/27/2020          Anhui  Mainland China
# 286        287      01/28/2020          Anhui  Mainland China
# 288        289      01/28/2020        Beijing  Mainland China
# ...

# %%
import pandas as pd 
df = pd.read_csv('covid_19_data.csv')
df.head(2)

# %%
#which state in mainland China recorded the highest number of confirmed cases

df = df[['Province/State','Confirmed']]
df

# %%
j= k[(k['Country/Region'] == 'Mainland China')] ['Confirmed']
j

# %%
l= k[(k['Country/Region'] == 'Mainland China') & k['Province/State']].groupby('Confirmed').max()
l.tail(5)

# %%
#show the number of confirmed cases and grouped by the number of deaths in the state of Hebei

l= k[(k['Country/Region'] == 'Mainland China') & (k['Province/State'] == 'Hebei')].groupby('Deaths').max()
l
